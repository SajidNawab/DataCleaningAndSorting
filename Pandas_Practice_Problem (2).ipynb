# %%
import pandas as pd
#read the Data and make Rank as index column

# %%
data
# Out:
#                           Name                    Industry  \
# Rank
# 1                      Walmart                      Retail
# 2                       Amazon  Retail and Cloud Computing
# 3                  Exxon Mobil          Petroleum industry
# 4                        Apple        Electronics industry
# 5           UnitedHealth Group                  Healthcare
# ...                        ...                         ...
# 96                    Best Buy                      Retail
# 97        Bristol-Myers Squibb     Pharmaceutical industry
# 98             United Airlines                     Airline
# 99    Thermo Fisher Scientific      Laboratory instruments
# 100                   Qualcomm                  Technology
#
#       Revenue (USD millions)  Revenue growth (%)  Employees  \
# Rank
# 1                     611289                 6.7    2100000
# 2                     513983                 9.4    1540000
# ...

# %%
""" Please retrieve detailed information about the columns in the DataFrame """
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1 to 100
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    100 non-null    object
#  1   Industry                100 non-null    object
#  2   Revenue (USD millions)  100 non-null    int64
#  3   Revenue growth (%)      100 non-null    float64
#  4   Employees               100 non-null    int64
#  5   Headquarters            100 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.5+ KB

# %%
""" Retrieve the Name of the Company which has most number of Employees """
# Out:
# ' Retrieve the Name of the Company which has most number of Employees '

# %%
""" Find the company with the highest revenue growth percentage """
# Out:
# ' Find the company with the highest revenue growth percentage '

# %%
""" Retrieve the top 5 Companies which have the highest Revenue """
# Out:
# ' Retrieve the top 5 Companies which have the highest Revenue '

# %%
""" How many companies in the data set have a revenue greater than 100 billion ($100000 million) (USD)? """
# Out:
# ' How many companies in the data set have a revenue greater than 100 billion ($100000 million) (USD)? '

# %%
""" Calculate the total revenue generated by all the companies in the data set. """
# Out:
# ' Calculate the total revenue generated by all the companies in the data set. '

# %%
""" Take all of the companies from the Retail Industry and print the average revenue generated by them """
# Out:
# ' Take all of the companies from the Retail Industry and print the average revenue generated by them '

# %%
""" Now do it using the groupby function """
# Out:
# ' Now do it using the groupby function '

# %%
""" Convert all the Industry Names to Uppercase letters """
# Out:
#                           Name                    Industry  \
# Rank
# 1                      Walmart                      RETAIL
# 2                       Amazon  RETAIL AND CLOUD COMPUTING
# 3                  Exxon Mobil          PETROLEUM INDUSTRY
# 4                        Apple        ELECTRONICS INDUSTRY
# 5           UnitedHealth Group                  HEALTHCARE
# ...                        ...                         ...
# 96                    Best Buy                      RETAIL
# 97        Bristol-Myers Squibb     PHARMACEUTICAL INDUSTRY
# 98             United Airlines                     AIRLINE
# 99    Thermo Fisher Scientific      LABORATORY INSTRUMENTS
# 100                   Qualcomm                  TECHNOLOGY
#
#       Revenue (USD millions)  Revenue growth (%)  Employees  \
# Rank
# 1                     611289                 6.7    2100000
# 2                     513983                 9.4    1540000
# ...

# %%
""" Use the apply function to make a new column of revenue per employee """
# Out:
#                           Name                    Industry  \
# Rank
# 1                      Walmart                      RETAIL
# 2                       Amazon  RETAIL AND CLOUD COMPUTING
# 3                  Exxon Mobil          PETROLEUM INDUSTRY
# 4                        Apple        ELECTRONICS INDUSTRY
# 5           UnitedHealth Group                  HEALTHCARE
# ...                        ...                         ...
# 96                    Best Buy                      RETAIL
# 97        Bristol-Myers Squibb     PHARMACEUTICAL INDUSTRY
# 98             United Airlines                     AIRLINE
# 99    Thermo Fisher Scientific      LABORATORY INSTRUMENTS
# 100                   Qualcomm                  TECHNOLOGY
#
#       Revenue (USD millions)  Revenue growth (%)  Employees  \
# Rank
# 1                     611289                 6.7    2100000
# 2                     513983                 9.4    1540000
# ...

# %%
""" Get the name of the companies which have Revenue Growth of > 10, Revenue greater than 250000 and is from PETROLEUM Industry or Airline """
# Out:
# ' Get the name of the companies which have Revenue Growth of > 10, Revenue greater than 250000 and is from PETROLEUM Industry or Airline '
